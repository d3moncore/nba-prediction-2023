# %%
import pandas as pd
import xgboost as xgb

# %%
df = pd.read_csv("C:\\Users\\sabar\\Downloads\\final.csv", index_col=0)

# %%
df.head(5)
# Out:
#       mp   mp.1    fg    fga    fg%    3p   3pa    3p%    ft   fta  ...  \
# 0  240.0  240.0  35.0   82.0  0.427  17.0  47.0  0.362  17.0  25.0  ...
# 1  240.0  240.0  43.0   96.0  0.448  10.0  34.0  0.294  10.0  17.0  ...
# 2  240.0  240.0  42.0  100.0  0.420  16.0  33.0  0.485   9.0  11.0  ...
# 3  240.0  240.0  41.0   84.0  0.488   6.0  23.0  0.261   9.0  14.0  ...
# 4  240.0  240.0  40.0   77.0  0.519   9.0  27.0  0.333  15.0  22.0  ...
#
#    tov%_max_opp  usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  \
# 0          33.3          30.5         142.0         107.0       CHO
# 1          41.0          38.7         249.0         111.0       BRK
# 2          50.0          43.2         125.0         123.0       SAC
# 3          33.3          30.7         236.0         107.0       NOP
# 4          13.2          38.9         207.0         121.0       CHI
#
#    total_opp  home_opp  season        date    won
# 0        106         1    2021  2020-12-27  False
# 1        104         0    2021  2020-12-27   True
# 2         97         1    2016  2016-01-13   True
# 3        109         0    2016  2016-01-13  False
# 4        117         1    2022  2022-01-19  False
#
# [5 rows x 150 columns]

# %%
df = df.sort_values("date")

# %%
df = df.reset_index(drop=True)

# %%
del df["mp.1"]
del df["mp_opp.1"]
del df["index_opp"]

# %%
def add_target(group):
    group["target"] = group["won"].shift(-1)
    return group

df = df.groupby("team", group_keys=False).apply(add_target)

# %%
df["target"][pd.isnull(df["target"])] = 2
df["target"] = df["target"].astype(int, errors="ignore")
# Out:
# C:\Users\sabar\AppData\Local\Temp\ipykernel_14044\2793819745.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["target"][pd.isnull(df["target"])] = 2

# %%
nulls = pd.isnull(df).sum()

# %%
nulls = nulls[nulls > 0]

# %%
valid_columns = df.columns[~df.columns.isin(nulls.index)]

# %%
valid_columns
# Out:
# Index(['mp', 'fg', 'fga', 'fg%', '3p', '3pa', '3p%', 'ft', 'fta', 'ft%',
#        ...
#        'usg%_max_opp', 'ortg_max_opp', 'drtg_max_opp', 'team_opp', 'total_opp',
#        'home_opp', 'season', 'date', 'won', 'target'],
#       dtype='object', length=142)
